# %%
import os
import numpy as np
import pandas as pd
import matplotlib as plt

#importing tools needed
#os to specif y the directory
#csv to read in csv files
#pandas to format data
#matplotlib to graph

filepath = os.path.join('nbadatasets')
datasets = os.listdir(filepath)

#defining the path where my data is located, datasets variable lists all of the files (.csv) in the directory

filelist = []
for file in datasets:
    filelist.append(file)
    
#Storing all of the csv data sets that I'm going to be working with into a list
#I can now iterate through the list of csv files to read in each dataframe

playerdata =[]
for player in filelist:
     playerdata.append(pd.read_csv(player))  

#Data for each of the players is stored in the list playerdata
#Each element of playerdata contains a dataframe corresponding to each player's index

age = []
pts = []
points_df = [age: pts]
for i in playerdata:
    age.append(column[2])
    pts.append(column[28])

a = []
b = []
rebounds_df = [a: b]
for j in playerdata:
    a.append(column[2])
    b.append(column[22])
    
c = []
d = []
assists_df = [c: d]
for k in playerdata:
    c.append(column[2])
    d.append(column[23])
    
#Appending the specific columns containing age (2) and points (28), age and rebounds (22), and age and assists (23) into lists
#Adding these lists to new dataframes, age is the key in each dict, and points, rebounds, and assists are the corresponding values
#For each of the 15 players, there should be a new row created in each data frame as you iterate through
    
    
plt.scatter(points_df, 'o')
m,b = np.polyfit(age, pts, 1)
plt.plot(age, pts, m*age+b)
plt.xlabel('Age')
plt.ylabel('Points')
plt.label('Age vs Points')
plt.show()

plt.scatter(rebounds_df, 'o')
y,z = np.polyfit(a, b, 1)
plt.plot(a, b, y*a+z)
plt.xlabel('Age')
plt.ylabel('Rebounds')
plt.label('Age vs Rebounds')
plt.show()

plt.scatter(assists_df, 'o')
r,s = np.polyfit(c, d, 1)
plt.plot(c, d, r*c+s)
plt.xlabel('Age')
plt.ylabel('Assists')
plt.label('Age vs Assists')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-cc95fab983cd> in <module>
#      24 playerdata =[]
#      25 for player in filelist:
# ---> 26      playerdata.append(pd.read_csv(player))
#      27
#      28 #Data for each of the players is stored in the list playerdata
#
# ...
